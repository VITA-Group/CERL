# %%
import os
import sys
import time
import argparse
from PIL import Image
# from generate_video import generate_video

import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from tqdm import tqdm
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import StepLR
from torchvision.models import vgg16
from perceptual import LossNetwork
import random

import config
import myutils
from myutils import test_images_2d, test_images_outp, test_metric, get_raft_args, test_images_optical
from loss import Loss
from loss import edge_conv2d
from torch.utils.data import DataLoader
from loss import L1_Charbonnier_loss
from pdb import set_trace as bp

import models
from utils import make_coord
from torch.autograd import Variable
from loss import PerceptualLoss, DCLoss

from core.raft import RAFT
from core.utils import flow_viz
from core.utils.utils import InputPadder

import cv2
from PWC_src import PWC_Net
from PWC_src import flow_to_image
import warnings

from dataset.GoPro_arbitrary_nosr import make_coord_3d


def double_forward(model, optimizer, preds, images, gt, device, i, epoch_id, bs):
    
    sampled_idx = sorted(random.sample(range(5), 3))
    h, w = preds[0].shape[2], preds[0].shape[3]
    for idx in range(3):
        optimizer.zero_grad()
        temp_coord = make_coord_3d((h, w), (idx + 2) / 8)
        temp_coord = [temp_coord.to(device)[None].repeat(bs, 1, 1)]
        if idx == 0:
            inputs = torch.cat([images[:, :, 1].unsqueeze(0), preds[1].detach().unsqueeze(0), preds[3].detach().unsqueeze(0), preds[5].detach().unsqueeze(0)], dim=0).permute(1, 2, 0, 3, 4)
        elif idx == 1:
            inputs = torch.cat([preds[0].detach().unsqueeze(0), preds[2].detach().unsqueeze(0), preds[4].detach().unsqueeze(0), preds[6].detach().unsqueeze(0)], dim=0).permute(1, 2, 0, 3, 4)
        else:
            inputs = torch.cat([preds[1].detach().unsqueeze(0), preds[3].detach().unsqueeze(0), preds[5].detach().unsqueeze(0), images[:, :, 2].unsqueeze(0)], dim=0).permute(1, 2, 0, 3, 4)
        new_pred_f, new_pred_b = model(inputs, temp_coord, True)
        loss = F.smooth_l1_loss(new_pred_f[0], gt[idx + 2])\
            + F.smooth_l1_loss(new_pred_b[0], gt[idx + 2])\
            + F.smooth_l1_loss(new_pred_b[0], new_pred_f[0])
        loss.backward()
        optimizer.step()
        print('Epoch %d, Iter %d, Loss: %.4f' % (epoch_id, i, loss.item()))
        
    return 
warnings.filterwarnings('ignore')

##### Tensorboard #####
writer = SummaryWriter('/output/logs')

##### Parameters #####
device_ids = [Id for Id in range(torch.cuda.device_count())]
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

parser = argparse.ArgumentParser()

parser.add_argument('--data_root', type=str, default='/data/nnice1216/vimeo_septuplet/DAVIS/JPEGImages/Full-Resolution/bmx-rider/')
parser.add_argument('--batch_size', type=int, default=4)
parser.add_argument('--lr', type=float, default=1e-5)
parser.add_argument('--epoch_num', type=int, default=30)
parser.add_argument('--num_workers', type=int, default=8)
parser.add_argument('--if_continue', type=bool, default=False)
parser.add_argument('--TEMP', type=float, default=1)

args = parser.parse_known_args()[0]

##### Dataset ###### 
## DAVIS 
# from dataset.Davis_liif import get_loader
# args.data_root = '/data/nnice1216/vimeo_septuplet/DAVIS/JPEGImages/Full-Resolution/bmx-rider/' 
# train_loader = get_loader(args.data_root, args.batch_size, shuffle=True, num_workers=8, drop_last=True)


## VIMEO ##
# from dataset.vimeo90k_septuplet import get_loader
# args.data_root = '/data/nnice1216/vimeo_septuplet/'
# train_loader = get_loader('train', args.data_root, args.batch_size, shuffle=True, num_workers=args.num_workers)


## GOPRO ##
from dataset.GoPro_arbitrary_nosr import get_loader
random_seed = 0
interval = 8
train_data_root = '/data/nnice1216/high_FPS_video/GOPRO_Large_all/'
# train_loader = get_loader('train', train_data_root, args.batch_size, shuffle=True, num_workers=args.num_workers, random_seed=random_seed, seted_interval=interval)
# train_loader = get_loader('train', train_data_root, args.batch_size, shuffle=True, num_workers=args.num_workers, random_seed=random_seed)


##### Model #####
## LIIF ###
model_args = {'encoder_spec': {'name': 'edsr-baseline', 'args': {'no_upsampling': True}}, 'imnet_spec': {'name': 'mlp', 'args': {'out_dim': 3, 'hidden_list': [64, 64]}}}
model_spec = {'name': 'liif_foroptical', 'args': model_args}
model = models.make(model_spec).to(device)
model = nn.DataParallel(model, device_ids=device_ids)
# for k, v in model.named_parameters():
#     if k[:14] == 'module.encoder':
#         v.requires_grad=False
        
# model.load_state_dict(torch.load('/model/nnice1216/video/FLAVR_2x.pth')['state_dict'], strict=False)

if args.if_continue:
    name = 'final-968.pth'
#     name = 'vimeo_epoch1_iter499.pth'
    print('Load model ' + name)
    model.load_state_dict(torch.load('/model/nnice1216/video/' + name))

##### Loss & Optimizer #####
optimizer = torch.optim.Adam(model.parameters(), lr=args.lr)
scheduler = StepLR(optimizer, step_size=1, gamma=0.8)

##### Training #####
model.train()
loss_f = PerceptualLoss(nn.MSELoss())
index = 0
# test_metric(model, 0, 0)
perc_lambda = 0.02
dcp_lambda = 0.005
FLOW_SCALE = 20.0

args1 = get_raft_args()
raft = RAFT(args1)
raft = nn.DataParallel(raft, device_ids=device_ids)
raft.load_state_dict(torch.load(args1.model))
raft.eval()
# new_state_dict = OrderedDict()
# pre_trained_dict = torch.load(args1.model)
# for k, v in pre_trained_dict.items():
#     name = k[7:]
#     new_state_dict[name] = v
# self.raft.load_state_dict(new_state_dict)
# self.raft.eval()
 
        
for epoch_id in range(args.epoch_num):
    
    print('Epoch {} Begin'.format(epoch_id))

    out_dir = '/output/models/'
    if not os.path.exists(out_dir):
        os.makedirs(out_dir)
    out_dir2 = '/output/tempimgs22/'
    if not os.path.exists(out_dir2):
        os.makedirs(out_dir2)
    train_loader = get_loader('train', train_data_root, args.batch_size, shuffle=True, num_workers=args.num_workers, random_seed=random_seed, seted_interval=interval)
    for i, data in enumerate(train_loader):
        
        ## VIMEO PRE_PROCESS FOR LIIF_3D ##
        images, gt_image, coords, cells, times = data
        images = [img_.to(device) for img_ in images]
        images = torch.stack(images, dim=2)
        gt = [g_.to(device) for g_ in gt_image]
        # gt = [g_.view(args.batch_size, 3, -1).permute(0, 2, 1).to(device) for g_ in gt_image]
        # gt = torch.cat(gt).view(args.batch_size, 3, -1).permute(0, 2, 1)
        coords = [c_.to(device) for c_ in coords]
        # coord, cell = coord.to(device), cell.to(device)
 
        # Forward
        optimizer.zero_grad()
        # pred_inter, pred_0, pred_1 = model(img, coord, cell)
        # bp()
        with torch.no_grad():
            padder = InputPadder(images[:, :, 1].shape)
            padder = InputPadder(images[:, :, 1].shape)
            image1, image2 = padder.pad(images[:, :, 1].clamp(0, 1) * 255, images[:, :, 2].clamp(0, 1) * 255)
            _, flow_f = raft(image1, image2, iters=20, test_mode=True)
        
        preds_f = model(images, coords, True)
        
        ## VISA ##
        # pred = model(img)
        # gt = img.clone().detach()
        ##  ##  ##
        
        # loss1 = F.smooth_l1_loss(preds[0], images[1].view(args.batch_size, 3, -1).permute(0, 2, 1)) + F.mse_loss(preds[-1], images[2].view(args.batch_size, 3, -1).permute(0, 2, 1))
        # loss1 = F.smooth_l1_loss(preds[0], images[1]) + F.smooth_l1_loss(preds[-1], images[2])
        # with torch.no_grad():
            # feature1 = vgg_model(images[1])
            # feature2 = vgg_model(images[2])
        # bp()
        loss1 = 0
        loss2 = 0
        loss3 = 0
        loss4 = 0
        for idx in range(1):
            '''
            with torch.no_grad():
                time = coords[idx][0, 0, -1].item()
                flow_f = FLOW_SCALE*pwc(images[:, :, 1], images[:, :, 2])
                flow_f = (flow_f - flow_f.min()) / (flow_f.max() - flow_f.min())
                # flow_b = FLOW_SCALE*pwc(images[:, :, 2], images[:, :, 1])
                # flow2 = FLOW_SCALE*pwc(images[:, :, 1], preds_f[idx])
            '''
            # loss1 += F.mse_loss(feature1, feature2) * 0.04
            # loss1 += F.smooth_l1_loss(preds[idx], gt[idx - 1])
            loss1 += F.smooth_l1_loss(preds_f[idx], flow_f)
            # loss2 += F.smooth_l1_loss(feats[idx][0], feats[idx][1])
            # loss2 += F.smooth_l1_loss(preds_b[idx], gt[idx])
            # loss3 += F.smooth_l1_loss(preds_f[idx], preds_b[idx])
            # loss4 += F.smooth_l1_loss(flow_f * time * (1 - time) - flow_b * (time ** 2), flow2) * 1e-3
            # loss2 += loss_f.get_loss(preds_f[idx], gt[idx]) * perc_lambda
            # loss3 += DCLoss(preds_f[idx].clamp(0, 1)) * dcp_lambda
            # loss2 += F.smooth_l1_loss(preds_b[idx], gt[idx]) + loss_f.get_loss(preds_b[idx], gt[idx]) * perc_lambda
            # loss3 += F.smooth_l1_loss(preds_f[idx], preds_b[idx]) + loss_f.get_loss(preds_f[idx], preds_b[idx]) * perc_lambda
            # loss2 += 0.1 * F.mse_loss(edge_conv2d(preds[idx]), edge_conv2d(gt[idx]))
            # loss2 += 0.05 * F.mse_loss(preds[idx], preds[idx - 1])
        
        # loss = F.mse_loss(preds[0], images[0].view(args.batch_size, 3, -1).permute(0, 2, 1)) + F.mse_loss(preds[-1], images[1].view(args.batch_size, 3, -1).permute(0, 2, 1))\
        #        + F.mse_loss(preds[1], gt[0]) + F.mse_loss(preds[2], gt[1]) + F.mse_loss(preds[3], gt[2]) + F.mse_loss(preds[4], gt[3]) + F.mse_loss(preds[5], gt[4])
        
        # loss1 = F.smooth_l1_loss(preds, gt[0])
        
        # Backward & Update
        # bp()
        loss = loss1 + loss2 + loss3 + loss4
        # loss *= 0.05
        # print(loss1.item(), loss2.item(), loss3.item(), loss4.item())
        # loss = loss1
        loss.backward()
        optimizer.step()
        
        print('Epoch %d, Iter %d, Loss: %.4f' % (epoch_id, i, loss.item()))
        # print('Loss1: %.4f, Loss2: %.4f' % (loss1.item(), loss2.item()))
        # print('Loss1: %.4f, Loss2: %.4f, Loss3: %.4f' % (loss1.item(), loss2.item(), loss3.item()))
        # print('Epoch %d, Iter %d, Loss1: %.4f, Loss2: %.4f, Loss: %.4f' % (epoch_id, i, loss1.item(), loss2.item(), loss.item()))
        writer.add_scalar('Training Loss', loss.item(), index)
        index += 1
        # index += 1
        
        if i % 50 == 0:
            Image.fromarray((gt_image[0][0].permute(1, 2, 0).numpy() * 255).astype(np.uint8)).save(os.path.join(out_dir2, 'Epoch{}_iter{}_GT.jpg'.format(epoch_id, i)))
            flow = preds_f[0].data.cpu()
            flow = flow[0].numpy().transpose((1,2,0))
            flow_im = flow_to_image(flow)
            Image.fromarray(flow_im).save(os.path.join(out_dir2, 'Epoch{}_iter{}_PRED.jpg'.format(epoch_id, i)))
        # Image.fromarray((preds[0][0].clamp(0, 1).view(192, 192, 3).detach().cpu().numpy() * 255).astype(np.uint8)).save(os.path.join(out_dir2, 'Epoch{}_iter{}.jpg'.format(epoch_id, i)))
        if i % 100 == 0:
            test_images_optical(model, device, 1 / 64, epoch_id, i)
            # test_images_3d(model, device, 0.85, epoch_id, i)
        if i % 100 == 20:
            test_images_optical(model, device, 8 / 64, epoch_id, i)
            # test_images_3d(model, device, 0.9, epoch_id, i)
        elif i % 100 == 40:
            test_images_optical(model, device, 32 / 64, epoch_id, i)
            # test_images_3d(model, device, 0.95, epoch_id, i)
        elif i % 100 == 60:
            test_images_optical(model, device, 48 / 64, epoch_id, i)
        elif i % 100 == 80:
            test_images_optical(model, device, 63 / 64, epoch_id, i)  
        model.train()
        # double_forward(model, optimizer, preds_f, images, gt, device, i, epoch_id, args.batch_size)
        
        if (i + 1) % 100 == 0:
            torch.save(model.state_dict(), '/output/models/vimeo_epoch{}_iter{}.pth'.format(epoch_id, i))
        if (i + 1) % 1000 == 0:
            test_metric(model, epoch_id, i)
    if epoch_id % 7 == 6:
        test_metric(model, epoch_id, i)
    print("Epoch {} Done. Index={}".format(epoch_id, index))
    # if epoch_id == 29:
    #     generate_video(model, epoch_id, device)
    
    # scheduler.step()
# Out:
# BATCHNORM:  False
# Epoch 0 Begin
# 1891
# 1891
# 1891
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-1-85f1056ec984> in <module>
#     185             padder = InputPadder(images[:, :, 1].shape)
#     186             image1, image2 = padder.pad(images[:, :, 1].clamp(0, 1) * 255, images[:, :, 2].clamp(0, 1) * 255)
# --> 187             _, flow_f = raft(image1, image2, iters=20, test_mode=True)
#     188
#     189         preds_f = model(images, coords, True)
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/parallel/data_parallel.py in forward(self, *inputs, **kwargs)
#     144                 raise RuntimeError("module must have its parameters and buffers "
#     145                                    "on device {} (device_ids[0]) but found one of "
# --> 146                                    "them on device: {}".format(self.src_device_obj, t.device))
#     147
#     148         inputs, kwargs = self.scatter(inputs, kwargs, self.device_ids)
#
# RuntimeError: module must have its parameters and buffers on device cuda:0 (device_ids[0]) but found one of them on device: cpu

# %%
import torchvision.transforms as tfs
from PIL import Image
import os
import myutils
from torch.utils.data import Dataset, DataLoader
from dataset.temp_test import TEMP

losses, psnrs, ssims = myutils.init_meters('1*L1')

test_loader = DataLoader(TEMP(), batch_size=8, shuffle=False, num_workers=8, drop_last=False)

for i, data in enumerate(test_loader):
    print(i, "DONE!")
    gt, pred = data
    gt, pred = gt.cuda(), pred.cuda()
    
    myutils.eval_metrics(gt, pred, psnrs, ssims)

    print('Val_PSNR:{0:.4f}, Val_SSIM:{1:.4f}'
          .format(psnrs.avg, ssims.avg))
# Out:
# ['000019.jpg', '000020.jpg', '000021.jpg', '000022.jpg', '000023.jpg', '000024.jpg', '000025.jpg', '000026.jpg', '000027.jpg', '000028.jpg', '000029.jpg', '000030.jpg', '000031.jpg', '000032.jpg', '000033.jpg', '000034.jpg', '000035.jpg', '000036.jpg', '000037.jpg', '000038.jpg', '000039.jpg', '000040.jpg', '000041.jpg', '000042.jpg', '000043.jpg', '000044.jpg', '000045.jpg', '000046.jpg', '000047.jpg', '000048.jpg', '000049.jpg', '000050.jpg', '000051.jpg', '000052.jpg', '000053.jpg', '000054.jpg', '000055.jpg', '000056.jpg', '000057.jpg', '000058.jpg', '000059.jpg', '000060.jpg', '000061.jpg', '000062.jpg', '000063.jpg', '000064.jpg', '000065.jpg', '000066.jpg', '000067.jpg', '000068.jpg', '000069.jpg', '000070.jpg', '000071.jpg', '000072.jpg', '000073.jpg', '000074.jpg', '000075.jpg', '000076.jpg', '000077.jpg', '000078.jpg', '000079.jpg', '000080.jpg', '000081.jpg', '000082.jpg', '000083.jpg', '000084.jpg', '000085.jpg', '000086.jpg', '000087.jpg', '000088.jpg', '000089.jpg', '000090.jpg', '000091.jpg', '000092.jpg', '000093.jpg', '000094.jpg', '000095.jpg', '000096.jpg', '000097.jpg', '000098.jpg', '000099.jpg', '000100.jpg', '000101.jpg', '000102.jpg', '000103.jpg', '000104.jpg', '000105.jpg', '000106.jpg', '000107.jpg', '000108.jpg', '000109.jpg', '000110.jpg', '000111.jpg', '000112.jpg', '000113.jpg', '000114.jpg', '000115.jpg', '000116.jpg', '000117.jpg', '000118.jpg', '000119.jpg', '000120.jpg', '000121.jpg', '000122.jpg', '000123.jpg', '000124.jpg', '000125.jpg', '000126.jpg', '000127.jpg', '000128.jpg', '000129.jpg', '000130.jpg', '000131.jpg', '000132.jpg', '000133.jpg', '000134.jpg', '000135.jpg', '000136.jpg', '000137.jpg', '000138.jpg', '000139.jpg', '000140.jpg', '000141.jpg', '000142.jpg', '000143.jpg', '000144.jpg', '000145.jpg', '000146.jpg', '000147.jpg', '000148.jpg', '000149.jpg', '000150.jpg', '000151.jpg', '000152.jpg', '000153.jpg', '000154.jpg', '000155.jpg', '000156.jpg', '000157.jpg', '000158.jpg', '000159.jpg', '000160.jpg', '000161.jpg', '000162.jpg', '000163.jpg', '000164.jpg', '000165.jpg', '000166.jpg', '000167.jpg', '000168.jpg', '000169.jpg', '000170.jpg', '000171.jpg', '000172.jpg', '000173.jpg', '000174.jpg', '000175.jpg', '000176.jpg', '000177.jpg', '000178.jpg', '000179.jpg', '000180.jpg', '000181.jpg', '000182.jpg', '000183.jpg', '000184.jpg', '000185.jpg', '000186.jpg', '000187.jpg', '000188.jpg', '000189.jpg', '000190.jpg', '000191.jpg', '000192.jpg', '000193.jpg', '000194.jpg', '000195.jpg', '000196.jpg', '000197.jpg', '000198.jpg', '000199.jpg', '000200.jpg', '000201.jpg', '000202.jpg', '000203.jpg', '000204.jpg', '000205.jpg', '000206.jpg', '000207.jpg', '000208.jpg', '000209.jpg', '000210.jpg', '000211.jpg', '000212.jpg', '000213.jpg', '000214.jpg', '000215.jpg', '000216.jpg', '000217.jpg', '000218.jpg', '000219.jpg', '000220.jpg', '000221.jpg', '000222.jpg', '000223.jpg', '000224.jpg', '000225.jpg', '000226.jpg', '000227.jpg', '000228.jpg', '000229.jpg', '000230.jpg', '000231.jpg', '000232.jpg', '000233.jpg', '000234.jpg', '000235.jpg', '000236.jpg', '000237.jpg', '000238.jpg', '000239.jpg', '000240.jpg', '000241.jpg', '000242.jpg', '000243.jpg', '000244.jpg', '000245.jpg', '000246.jpg', '000247.jpg', '000248.jpg', '000249.jpg', '000250.jpg', '000251.jpg', '000252.jpg', '000253.jpg', '000254.jpg', '000255.jpg', '000256.jpg', '000257.jpg', '000258.jpg', '000259.jpg', '000260.jpg', '000261.jpg', '000262.jpg', '000263.jpg', '000264.jpg', '000265.jpg', '000266.jpg', '000267.jpg', '000268.jpg', '000269.jpg', '000270.jpg', '000271.jpg', '000272.jpg', '000273.jpg', '000274.jpg', '000275.jpg', '000276.jpg', '000277.jpg', '000278.jpg', '000279.jpg', '000280.jpg', '000281.jpg', '000282.jpg', '000283.jpg', '000284.jpg', '000285.jpg', '000286.jpg', '000287.jpg', '000288.jpg', '000289.jpg', '000290.jpg', '000291.jpg', '000292.jpg', '000293.jpg', '000294.jpg', '000295.jpg', '000296.jpg', '000297.jpg', '000298.jpg', '000299.jpg', '000300.jpg', '000301.jpg', '000302.jpg', '000303.jpg', '000304.j ...
# 1050
# 0 DONE!
# Val_PSNR:27.2533, Val_SSIM:0.8649
# 1 DONE!
# Val_PSNR:27.8196, Val_SSIM:0.8744
# 2 DONE!
# Val_PSNR:26.6782, Val_SSIM:0.8574
# 3 DONE!
# Val_PSNR:26.7495, Val_SSIM:0.8573
# 4 DONE!
# Val_PSNR:26.4551, Val_SSIM:0.8560
# 5 DONE!
# Val_PSNR:26.9366, Val_SSIM:0.8655
# 6 DONE!
# Val_PSNR:26.2385, Val_SSIM:0.8503
# 7 DONE!
# Val_PSNR:26.8078, Val_SSIM:0.8594
# 8 DONE!
# Val_PSNR:26.6538, Val_SSIM:0.8577
# 9 DONE!
# Val_PSNR:26.7643, Val_SSIM:0.8584
# 10 DONE!
# Val_PSNR:26.5355, Val_SSIM:0.8541
# 11 DONE!
# Val_PSNR:26.5990, Val_SSIM:0.8540
# 12 DONE!
# Val_PSNR:26.7104, Val_SSIM:0.8576
# 13 DONE!
# Val_PSNR:27.0617, Val_SSIM:0.8633
# 14 DONE!
# Val_PSNR:27.0071, Val_SSIM:0.8630
# 15 DONE!
# Val_PSNR:27.1678, Val_SSIM:0.8655
# 16 DONE!
# Val_PSNR:27.0373, Val_SSIM:0.8627
# 17 DONE!
# Val_PSNR:26.9953, Val_SSIM:0.8606
# 18 DONE!
# Val_PSNR:26.6914, Val_SSIM:0.8529
# 19 DONE!
# Val_PSNR:26.5501, Val_SSIM:0.8477
# 20 DONE!
# Val_PSNR:26.2044, Val_SSIM:0.8381
# 21 DONE!
# Val_PSNR:26.2086, Val_SSIM:0.8373
# 22 DONE!
# Val_PSNR:26.0400, Val_SSIM:0.8327
# 23 DONE!
# Val_PSNR:26.0641, Val_SSIM:0.8322
# 24 DONE!
# Val_PSNR:25.9035, Val_SSIM:0.8290
# 25 DONE!
# Val_PSNR:25.8278, Val_SSIM:0.8267
# 26 DONE!
# Val_PSNR:25.6314, Val_SSIM:0.8220
# 27 DONE!
# Val_PSNR:25.6883, Val_SSIM:0.8228
# 28 DONE!
# Val_PSNR:25.6370, Val_SSIM:0.8226
# 29 DONE!
# Val_PSNR:25.7820, Val_SSIM:0.8254
# 30 DONE!
# Val_PSNR:25.7026, Val_SSIM:0.8237
# 31 DONE!
# Val_PSNR:25.7572, Val_SSIM:0.8246
# 32 DONE!
# Val_PSNR:25.6625, Val_SSIM:0.8230
# 33 DONE!
# Val_PSNR:25.8172, Val_SSIM:0.8261
# 34 DONE!
# Val_PSNR:25.8254, Val_SSIM:0.8270
# 35 DONE!
# Val_PSNR:25.8271, Val_SSIM:0.8266
# 36 DONE!
# Val_PSNR:25.7159, Val_SSIM:0.8240
# 37 DONE!
# Val_PSNR:25.7749, Val_SSIM:0.8250
# 38 DONE!
# Val_PSNR:25.8048, Val_SSIM:0.8264
# 39 DONE!
# Val_PSNR:25.8943, Val_SSIM:0.8283
# 40 DONE!
# Val_PSNR:25.9892, Val_SSIM:0.8306
# 41 DONE!
# Val_PSNR:26.1468, Val_SSIM:0.8333
# 42 DONE!
# Val_PSNR:26.1618, Val_SSIM:0.8342
# 43 DONE!
# Val_PSNR:26.2810, Val_SSIM:0.8364
# 44 DONE!
# Val_PSNR:26.3630, Val_SSIM:0.8384
# 45 DONE!
# Val_PSNR:26.4817, Val_SSIM:0.8407
# 46 DONE!
# Val_PSNR:26.5124, Val_SSIM:0.8418
# 47 DONE!
# Val_PSNR:26.6284, Val_SSIM:0.8438
# 48 DONE!
# Val_PSNR:26.5858, Val_SSIM:0.8432
# 49 DONE!
# Val_PSNR:26.7072, Val_SSIM:0.8452
# 50 DONE!
# Val_PSNR:26.7985, Val_SSIM:0.8470
# 51 DONE!
# Val_PSNR:26.9357, Val_SSIM:0.8491
# 52 DONE!
# Val_PSNR:26.9683, Val_SSIM:0.8500
# 53 DONE!
# Val_PSNR:26.9644, Val_SSIM:0.8499
# 54 DONE!
# Val_PSNR:27.0428, Val_SSIM:0.8515
# 55 DONE!
# Val_PSNR:27.1580, Val_SSIM:0.8534
# 56 DONE!
# Val_PSNR:27.1719, Val_SSIM:0.8543
# 57 DONE!
# Val_PSNR:27.2260, Val_SSIM:0.8554
# 58 DONE!
# Val_PSNR:27.1965, Val_SSIM:0.8552
# 59 DONE!
# Val_PSNR:27.2400, Val_SSIM:0.8560
# 60 DONE!
# Val_PSNR:27.1918, Val_SSIM:0.8553
# 61 DONE!
# Val_PSNR:27.2352, Val_SSIM:0.8562
# 62 DONE!
# Val_PSNR:27.2254, Val_SSIM:0.8565
# 63 DONE!
# Val_PSNR:27.2740, Val_SSIM:0.8576
# 64 DONE!
# Val_PSNR:27.3030, Val_SSIM:0.8585
# 65 DONE!
# Val_PSNR:27.3644, Val_SSIM:0.8597
# 66 DONE!
# Val_PSNR:27.4119, Val_SSIM:0.8608
# 67 DONE!
# Val_PSNR:27.4871, Val_SSIM:0.8621
# 68 DONE!
# Val_PSNR:27.4670, Val_SSIM:0.8621
# 69 DONE!
# Val_PSNR:27.5331, Val_SSIM:0.8633
# 70 DONE!
# Val_PSNR:27.5441, Val_SSIM:0.8638
# 71 DONE!
# Val_PSNR:27.5601, Val_SSIM:0.8641
# 72 DONE!
# Val_PSNR:27.5644, Val_SSIM:0.8646
# 73 DONE!
# Val_PSNR:27.6401, Val_SSIM:0.8658
# 74 DONE!
# Val_PSNR:27.6243, Val_SSIM:0.8656
# 75 DONE!
# Val_PSNR:27.6215, Val_SSIM:0.8654
# 76 DONE!
# Val_PSNR:27.6085, Val_SSIM:0.8655
# 77 DONE!
# Val_PSNR:27.6418, Val_SSIM:0.8662
# 78 DONE!
# Val_PSNR:27.6021, Val_SSIM:0.8656
# 79 DONE!
# Val_PSNR:27.5939, Val_SSIM:0.8654
# 80 DONE!
# Val_PSNR:27.5155, Val_SSIM:0.8637
# 81 DONE!
# Val_PSNR:27.5164, Val_SSIM:0.8636
# 82 DONE!
# Val_PSNR:27.4477, Val_SSIM:0.8620
# 83 DONE!
# Val_PSNR:27.4606, Val_SSIM:0.8623
# 84 DONE!
# Val_PSNR:27.3961, Val_SSIM:0.8609
# 85 DONE!
# Val_PSNR:27.4101, Val_SSIM:0.8610
# 86 DONE!
# Val_PSNR:27.3847, Val_SSIM:0.8607
# 87 DONE!
# Val_PSNR:27.4195, Val_SSIM:0.8612
# 88 DONE!
# Val_PSNR:27.3710, Val_SSIM:0.8600
# 89 DONE!
# Val_PSNR:27.3675, Val_SSIM:0.8597
# 90 DONE!
# Val_PSNR:27.3806, Val_SSIM:0.8601
# 91 DONE!
# Val_PSNR:27.4213, Val_SSIM:0.8607
# 92 DONE!
# Val_PSNR:27.4070, Val_SSIM:0.8606
# 93 DONE!
# Val_PSNR:27.4062, Val_SSIM:0.8604
# 94 DONE!
# Val_PSNR:27.4320, Val_SSIM:0.8610
# 95 DONE!
# Val_PSNR:27.4373, Val_SSIM:0.8611
# 96 DONE!
# Val_PSNR:27.4181, Val_SSIM:0.8609
# 97 DONE!
# Val_PSNR:27.4661, Val_SSIM:0.8616
# 98 DONE!
# Val_PSNR:27.4457, Val_SSIM:0.8614
# 99 DONE!
# Val_PSNR:27.4947, Val_SSIM:0.8622
# 100 DONE!
# Val_PSNR:27.4902, Val_SSIM:0.8623
# 101 DONE!
# Val_PSNR:27.5009, Val_SSIM:0.8627
# 102 DONE!
# Val_PSNR:27.4720, Val_SSIM:0.8623
# 103 DONE!
# Val_PSNR:27.4980, Val_SSIM:0.8629
# 104 DONE!
# Val_PSNR:27.4817, Val_SSIM:0.8628
# 105 DONE!
# Val_PSNR:27.4775, Val_SSIM:0.8628
# 106 DONE!
# Val_PSNR:27.4267, Val_SSIM:0.8617
# 107 DONE!
# Val_PSNR:27.4302, Val_SSIM:0.8618
# 108 DONE!
# Val_PSNR:27.4078, Val_SSIM:0.8615
# 109 DONE!
# Val_PSNR:27.4170, Val_SSIM:0.8618
# 110 DONE!
# Val_PSNR:27.4251, Val_SSIM:0.8621
# 111 DONE!
# Val_PSNR:27.4396, Val_SSIM:0.8624
# 112 DONE!
# Val_PSNR:27.4162, Val_SSIM:0.8620
# 113 DONE!
# Val_PSNR:27.4363, Val_SSIM:0.8624
# 114 DONE!
# Val_PSNR:27.4583, Val_SSIM:0.8630
# 115 DONE!
# Val_PSNR:27.4524, Val_SSIM:0.8629
# 116 DONE!
# Val_PSNR:27.4242, Val_SSIM:0.8625
# 117 DONE!
# Val_PSNR:27.4429, Val_SSIM:0.8629
# 118 DONE!
# Val_PSNR:27.4133, Val_SSIM:0.8624
# 119 DONE!
# Val_PSNR:27.4266, Val_SSIM:0.8627
# 120 DONE!
# Val_PSNR:27.4317, Val_SSIM:0.8631
# 121 DONE!
# Val_PSNR:27.4562, Val_SSIM:0.8636
# 122 DONE!
# Val_PSNR:27.4561, Val_SSIM:0.8638
# 123 DONE!
# Val_PSNR:27.4731, Val_SSIM:0.8642
# 124 DONE!
# Val_PSNR:27.4456, Val_SSIM:0.8637
# 125 DONE!
# Val_PSNR:27.4618, Val_SSIM:0.8640
# 126 DONE!
# Val_PSNR:27.4494, Val_SSIM:0.8639
# 127 DONE!
# Val_PSNR:27.4574, Val_SSIM:0.8641
# 128 DONE!
# Val_PSNR:27.4294, Val_SSIM:0.8637
# 129 DONE!
# Val_PSNR:27.4592, Val_SSIM:0.8643
# 130 DONE!
# Val_PSNR:27.4260, Val_SSIM:0.8637
# 131 DONE!
# Val_PSNR:27.4201, Val_SSIM:0.8637

# %%
import os
import sys
import time
import copy
import shutil
import random
import pdb

import torch
import numpy as np
from tqdm import tqdm

import config
import myutils
import models

from PIL import Image
import torch.nn as nn
from torch.utils.data import DataLoader
from pdb import set_trace as bp


##### Parse CmdLine Arguments #####
# os.environ["CUDA_VISIBLE_DEVICES"]='7'
args, unparsed = config.get_args()
cwd = os.getcwd()

device_ids = [Id for Id in range(torch.cuda.device_count())]
device = torch.device('cuda' if args.cuda else 'cpu')

torch.manual_seed(args.random_seed)
if args.cuda:
    torch.cuda.manual_seed(args.random_seed)

##### FLAVR #####

model_args = {'encoder_spec': {'name': 'edsr-baseline', 'args': {'no_upsampling': True}}, 'imnet_spec': {'name': 'mlp', 'args': {'out_dim': 3, 'hidden_list': [64, 64]}}}
model_spec = {'name': 'liif_bidi', 'args': model_args}
model = models.make(model_spec).to(device)
model = nn.DataParallel(model, device_ids=device_ids)
name = '633-best-21-22.pth'
model.load_state_dict(torch.load('/model/nnice1216/video/' + name))


def get_name(index):
    if index >= 0 and index <= 9:
        text = '00000' + str(index) + '.jpg'
    elif index >= 10 and index <= 99:
        text = '0000' + str(index) + '.jpg'
    elif index >= 100 and index <= 999:
        text = '000' + str(index) + '.jpg'
    else:
        text = '00' + str(index) + '.jpg'
    return text

def save_image(img, index):
    if index < 1600:
        img.save(os.path.join(out_path1, get_name(index)))
    elif index < 3200:
        img.save(os.path.join(out_path2, get_name(index)))
    elif index < 4800:
        img.save(os.path.join(out_path3, get_name(index)))
    elif index < 6400:
        img.save(os.path.join(out_path4, get_name(index)))
    elif index < 8000:
        img.save(os.path.join(out_path5, get_name(index)))
    elif index < 9600:
        img.save(os.path.join(out_path6, get_name(index)))
    else:
        img.save(os.path.join(out_path7, get_name(index)))
        

def test(model, epoch_id, iter_id):
    
    out_path1 = '/output/Imagestry11/'
    out_path2 = '/output/Imagestry2/'
    out_path3 = '/output/Imagestry3/'
    out_path4 = '/output/Imagestry4/'
    out_path5 = '/output/Imagestry5/'
    out_path6 = '/output/Imagestry6/'
    out_path7 = '/output/Imagestry7/'
    if not os.path.exists(out_path1):
        os.makedirs(out_path1)
    if not os.path.exists(out_path2):
        os.makedirs(out_path2)
    if not os.path.exists(out_path3):
        os.makedirs(out_path3)
    if not os.path.exists(out_path4):
        os.makedirs(out_path4)
    if not os.path.exists(out_path5):
        os.makedirs(out_path5)
    if not os.path.exists(out_path6):
        os.makedirs(out_path6)
    if not os.path.exists(out_path7):
        os.makedirs(out_path7)
        
    torch.cuda.empty_cache()
    from dataset.GoPro_singlevideo import get_loader as gl
    test_loader = gl('train', '/data/nnice1216/high_FPS_video/GOPRO_Large_all/GOPR0384_11_00/', 1, shuffle=False, num_workers=8, interFrames=15)    
    # test_loader = gl('train', '/output/liif_result/', 1, shuffle=False, num_workers=8, interFrames=15)
    
    time_taken = []
    losses, psnrs, ssims = myutils.init_meters('1*L1')
    model.eval()
    save_index = 17
    psnr_list = []
    outpath = '/output/liif_result/'
    if not os.path.exists(outpath):
        os.makedirs(outpath)
        
    with torch.no_grad():
        for i, (images, coords, cells, times, names) in enumerate(test_loader):
            print(names[1][0].split('/')[-1][:6], "SHOULD EQUAL TO {}, DONE".format(save_index))

            images = [img_.cuda() for img_ in images]
            coords = [coords[0].cuda()]
            # coords = [c_.cuda() for c_ in coords]
            # cells = [c_.cuda() for c_ in cells]
            
            Image.fromarray((images[1][0].permute(1, 2, 0).detach().cpu() * 255).numpy().astype(np.uint8)).save(os.path.join(out_path1, get_name(save_index)))
            print(save_index, "DONE!")
            save_index += 1
            
            torch.cuda.synchronize()
            start_time = time.time()
            # out = model(images)
            
            out = model(images, coords, 8, save_index)
            save_index += 14
            torch.cuda.synchronize()
            time_taken.append(time.time() - start_time)
            print(os.path.join(out_path1, get_name(save_index)))
            Image.fromarray((out[0].clamp(0, 1).permute(1, 2, 0).detach().cpu() * 255).numpy().astype(np.uint8)).save(os.path.join(out_path1, get_name(save_index)))
            print(save_index, "DONE!")
            save_index += 1
            
            del images
            torch.cuda.empty_cache()        
    # print("PSNR: %f, SSIM: %f" %
    #       (psnrs.avg, ssims.avg))
    # print("Time: " , sum(time_taken)/len(time_taken))
    torch.cuda.empty_cache()
    return


""" Entry Point """
def main(args):
    
    assert args.load_from is not None

    test(model, 1, 1)


if __name__ == "__main__":
    main(args)
# Out:
# Unparsed args: ['-f', '/root/.local/share/jupyter/runtime/kernel-264af218-60f9-4bb3-ba8b-ebed003b01fe.json']
# BATCHNORM:  False
# 66
# 000017 SHOULD EQUAL TO 17, DONE
# 17 DONE!
# INDEX 18, DONE!
# INDEX 19, DONE!
# INDEX 20, DONE!
# INDEX 21, DONE!
# INDEX 22, DONE!
# INDEX 23, DONE!
# INDEX 24, DONE!
# INDEX 25, DONE!
# INDEX 26, DONE!
# INDEX 27, DONE!
# INDEX 28, DONE!
# INDEX 29, DONE!
# INDEX 30, DONE!
# INDEX 31, DONE!
# /output/Imagestry11/000032.jpg
# 32 DONE!
# 000033 SHOULD EQUAL TO 33, DONE
# 33 DONE!
# INDEX 34, DONE!
# INDEX 35, DONE!
# INDEX 36, DONE!
# INDEX 37, DONE!
# INDEX 38, DONE!
# INDEX 39, DONE!
# INDEX 40, DONE!
# INDEX 41, DONE!
# INDEX 42, DONE!
# INDEX 43, DONE!
# INDEX 44, DONE!
# INDEX 45, DONE!
# INDEX 46, DONE!
# INDEX 47, DONE!
# /output/Imagestry11/000048.jpg
# 48 DONE!
# 000049 SHOULD EQUAL TO 49, DONE
# 49 DONE!
# INDEX 50, DONE!
# INDEX 51, DONE!
# INDEX 52, DONE!
# INDEX 53, DONE!
# INDEX 54, DONE!
# INDEX 55, DONE!
# INDEX 56, DONE!
# INDEX 57, DONE!
# INDEX 58, DONE!
# INDEX 59, DONE!
# INDEX 60, DONE!
# INDEX 61, DONE!
# INDEX 62, DONE!
# INDEX 63, DONE!
# /output/Imagestry11/000064.jpg
# 64 DONE!
# 000065 SHOULD EQUAL TO 65, DONE
# 65 DONE!
# INDEX 66, DONE!
# INDEX 67, DONE!
# INDEX 68, DONE!
# INDEX 69, DONE!
# INDEX 70, DONE!
# INDEX 71, DONE!
# INDEX 72, DONE!
# INDEX 73, DONE!
# INDEX 74, DONE!
# INDEX 75, DONE!
# INDEX 76, DONE!
# INDEX 77, DONE!
# INDEX 78, DONE!
# INDEX 79, DONE!
# /output/Imagestry11/000080.jpg
# 80 DONE!
# 000081 SHOULD EQUAL TO 81, DONE
# 81 DONE!
# INDEX 82, DONE!
# INDEX 83, DONE!
# INDEX 84, DONE!
# INDEX 85, DONE!
# INDEX 86, DONE!
# INDEX 87, DONE!
# INDEX 88, DONE!
# INDEX 89, DONE!
# INDEX 90, DONE!
# INDEX 91, DONE!
# INDEX 92, DONE!
# INDEX 93, DONE!
# INDEX 94, DONE!
# INDEX 95, DONE!
# /output/Imagestry11/000096.jpg
# 96 DONE!
# 000097 SHOULD EQUAL TO 97, DONE
# 97 DONE!
# INDEX 98, DONE!
# INDEX 99, DONE!
# INDEX 100, DONE!
# INDEX 101, DONE!
# INDEX 102, DONE!
# INDEX 103, DONE!
# INDEX 104, DONE!
# INDEX 105, DONE!
# INDEX 106, DONE!
# INDEX 107, DONE!
# INDEX 108, DONE!
# INDEX 109, DONE!
# INDEX 110, DONE!
# INDEX 111, DONE!
# /output/Imagestry11/000112.jpg
# 112 DONE!
# 000113 SHOULD EQUAL TO 113, DONE
# 113 DONE!
# INDEX 114, DONE!
# INDEX 115, DONE!
# INDEX 116, DONE!
# INDEX 117, DONE!
# INDEX 118, DONE!
# INDEX 119, DONE!
# INDEX 120, DONE!
# INDEX 121, DONE!
# INDEX 122, DONE!
# INDEX 123, DONE!
# INDEX 124, DONE!
# INDEX 125, DONE!
# INDEX 126, DONE!
# INDEX 127, DONE!
# /output/Imagestry11/000128.jpg
# 128 DONE!
# 000129 SHOULD EQUAL TO 129, DONE
# 129 DONE!
# INDEX 130, DONE!
# INDEX 131, DONE!
# INDEX 132, DONE!
# INDEX 133, DONE!
# INDEX 134, DONE!
# INDEX 135, DONE!
# INDEX 136, DONE!
# INDEX 137, DONE!
# INDEX 138, DONE!
# INDEX 139, DONE!
# INDEX 140, DONE!
# INDEX 141, DONE!
# INDEX 142, DONE!
# INDEX 143, DONE!
# /output/Imagestry11/000144.jpg
# 144 DONE!
# 000145 SHOULD EQUAL TO 145, DONE
# 145 DONE!
# INDEX 146, DONE!
# INDEX 147, DONE!
# INDEX 148, DONE!
# INDEX 149, DONE!
# INDEX 150, DONE!
# INDEX 151, DONE!
# INDEX 152, DONE!
# INDEX 153, DONE!
# INDEX 154, DONE!
# INDEX 155, DONE!
# INDEX 156, DONE!
# INDEX 157, DONE!
# INDEX 158, DONE!
# INDEX 159, DONE!
# /output/Imagestry11/000160.jpg
# 160 DONE!
# 000161 SHOULD EQUAL TO 161, DONE
# 161 DONE!
# INDEX 162, DONE!
# INDEX 163, DONE!
# INDEX 164, DONE!
# INDEX 165, DONE!
# INDEX 166, DONE!
# INDEX 167, DONE!
# INDEX 168, DONE!
# INDEX 169, DONE!
# INDEX 170, DONE!
# INDEX 171, DONE!
# INDEX 172, DONE!
# INDEX 173, DONE!
# INDEX 174, DONE!
# INDEX 175, DONE!
# /output/Imagestry11/000176.jpg
# 176 DONE!
# 000177 SHOULD EQUAL TO 177, DONE
# 177 DONE!
# INDEX 178, DONE!
# INDEX 179, DONE!
# INDEX 180, DONE!
# INDEX 181, DONE!
# INDEX 182, DONE!
# INDEX 183, DONE!
# INDEX 184, DONE!
# INDEX 185, DONE!
# INDEX 186, DONE!
# INDEX 187, DONE!
# INDEX 188, DONE!
# INDEX 189, DONE!
# INDEX 190, DONE!
# INDEX 191, DONE!
# /output/Imagestry11/000192.jpg
# 192 DONE!
# 000193 SHOULD EQUAL TO 193, DONE
# 193 DONE!
# INDEX 194, DONE!
# INDEX 195, DONE!
# INDEX 196, DONE!
# INDEX 197, DONE!
# INDEX 198, DONE!
# INDEX 199, DONE!
# INDEX 200, DONE!
# INDEX 201, DONE!
# INDEX 202, DONE!
# INDEX 203, DONE!
# INDEX 204, DONE!
# INDEX 205, DONE!
# INDEX 206, DONE!
# INDEX 207, DONE!
# /output/Imagestry11/000208.jpg
# 208 DONE!
# 000209 SHOULD EQUAL TO 209, DONE
# 209 DONE!
# INDEX 210, DONE!
# INDEX 211, DONE!
# INDEX 212, DONE!
# INDEX 213, DONE!
# INDEX 214, DONE!
# INDEX 215, DONE!
# INDEX 216, DONE!
# INDEX 217, DONE!
# INDEX 218, DONE!
# INDEX 219, DONE!
# INDEX 220, DONE!
# INDEX 221, DONE!
# INDEX 222, DONE!
# INDEX 223, DONE!
# /output/Imagestry11/000224.jpg
# 224 DONE!
# 000225 SHOULD EQUAL TO 225, DONE
# 225 DONE!
# INDEX 226, DONE!
# INDEX 227, DONE!
# INDEX 228, DONE!
# INDEX 229, DONE!
# INDEX 230, DONE!
# INDEX 231, DONE!
# INDEX 232, DONE!
# INDEX 233, DONE!
# INDEX 234, DONE!
# INDEX 235, DONE!
# INDEX 236, DONE!
# INDEX 237, DONE!
# INDEX 238, DONE!
# INDEX 239, DONE!
# /output/Imagestry11/000240.jpg
# 240 DONE!
# 000241 SHOULD EQUAL TO 241, DONE
# 241 DONE!
# INDEX 242, DONE!
# INDEX 243, DONE!
# INDEX 244, DONE!
# INDEX 245, DONE!
# INDEX 246, DONE!
# INDEX 247, DONE!
# INDEX 248, DONE!
# INDEX 249, DONE!
# INDEX 250, DONE!
# INDEX 251, DONE!
# INDEX 252, DONE!
# INDEX 253, DONE!
# INDEX 254, DONE!
# INDEX 255, DONE!
# /output/Imagestry11/000256.jpg
# 256 DONE!
# 000257 SHOULD EQUAL TO 257, DONE
# 257 DONE!
# INDEX 258, DONE!
# INDEX 259, DONE!
# INDEX 260, DONE!
# INDEX 261, DONE!
# INDEX 262, DONE!
# INDEX 263, DONE!
# INDEX 264, DONE!
# INDEX 265, DONE!
# INDEX 266, DONE!
# INDEX 267, DONE!
# INDEX 268, DONE!
# INDEX 269, DONE!
# INDEX 270, DONE!
# INDEX 271, DONE!
# /output/Imagestry11/000272.jpg
# 272 DONE!
# 000273 SHOULD EQUAL TO 273, DONE
# 273 DONE!
# INDEX 274, DONE!
# INDEX 275, DONE!
# INDEX 276, DONE!
# INDEX 277, DONE!
# INDEX 278, DONE!
# INDEX 279, DONE!
# INDEX 280, DONE!
# INDEX 281, DONE!
# INDEX 282, DONE!
# INDEX 283, DONE!
# INDEX 284, DONE!
# INDEX 285, DONE!
# INDEX 286, DONE!
# INDEX 287, DONE!
# /output/Imagestry11/000288.jpg
# 288 DONE!
# 000289 SHOULD EQUAL TO 289, DONE
# 289 DONE!
# INDEX 290, DONE!
# INDEX 291, DONE!
# INDEX 292, DONE!
# INDEX 293, DONE!
# INDEX 294, DONE!
# INDEX 295, DONE!
# INDEX 296, DONE!
# INDEX 297, DONE!
# INDEX 298, DONE!
# INDEX 299, DONE!
# INDEX 300, DONE!
# INDEX 301, DONE!
# INDEX 302, DONE!
# INDEX 303, DONE!
# /output/Imagestry11/000304.jpg
# 304 DONE!
# 000305 SHOULD EQUAL TO 305, DONE
# 305 DONE!
# INDEX 306, DONE!
# INDEX 307, DONE!
# INDEX 308, DONE!
# INDEX 309, DONE!
# INDEX 310, DONE!
# INDEX 311, DONE!
# INDEX 312, DONE!
# INDEX 313, DONE!
# INDEX 314, DONE!
# INDEX 315, DONE!
# INDEX 316, DONE!
# INDEX 317, DONE!
# INDEX 318, DONE!
# INDEX 319, DONE!
# /output/Imagestry11/000320.jpg
# 320 DONE!
# 000321 SHOULD EQUAL TO 321, DONE
# 321 DONE!
# INDEX 322, DONE!
# INDEX 323, DONE!
# INDEX 324, DONE!
# INDEX 325, DONE!
# INDEX 326, DONE!
# INDEX 327, DONE!
# INDEX 328, DONE!
# INDEX 329, DONE!
# INDEX 330, DONE!
# INDEX 331, DONE!
# INDEX 332, DONE!
# INDEX 333, DONE!
# INDEX 334, DONE!
# INDEX 335, DONE!
# /output/Imagestry11/000336.jpg
# 336 DONE!
# 000337 SHOULD EQUAL TO 337, DONE
# 337 DONE!
# INDEX 338, DONE!
# INDEX 339, DONE!
# INDEX 340, DONE!
# INDEX 341, DONE!
# INDEX 342, DONE!
# INDEX 343, DONE!
# INDEX 344, DONE!
# INDEX 345, DONE!
# INDEX 346, DONE!
# INDEX 347, DONE!
# INDEX 348, DONE!
# INDEX 349, DONE!
# INDEX 350, DONE!
# INDEX 351, DONE!
# /output/Imagestry11/000352.jpg
# 352 DONE!
# 000353 SHOULD EQUAL TO 353, DONE
# 353 DONE!
# INDEX 354, DONE!
# INDEX 355, DONE!
# INDEX 356, DONE!
# INDEX 357, DONE!
# INDEX 358, DONE!
# INDEX 359, DONE!
# INDEX 360, DONE!
# INDEX 361, DONE!
# INDEX 362, DONE!
# INDEX 363, DONE!
# INDEX 364, DONE!
# INDEX 365, DONE!
# INDEX 366, DONE!
# INDEX 367, DONE!
# /output/Imagestry11/000368.jpg
# 368 DONE!
# 000369 SHOULD EQUAL TO 369, DONE
# 369 DONE!
# INDEX 370, DONE!
# INDEX 371, DONE!
# INDEX 372, DONE!
# INDEX 373, DONE!
# INDEX 374, DONE!
# INDEX 375, DONE!
# INDEX 376, DONE!
# INDEX 377, DONE!
# INDEX 378, DONE!
# INDEX 379, DONE!
# INDEX 380, DONE!
# INDEX 381, DONE!
# INDEX 382, DONE!
# INDEX 383, DONE!
# /output/Imagestry11/000384.jpg
# 384 DONE!
# 000385 SHOULD EQUAL TO 385, DONE
# 385 DONE!
# INDEX 386, DONE!
# INDEX 387, DONE!
# INDEX 388, DONE!
# INDEX 389, DONE!
# INDEX 390, DONE!
# INDEX 391, DONE!
# INDEX 392, DONE!
# INDEX 393, DONE!
# INDEX 394, DONE!
# INDEX 395, DONE!
# INDEX 396, DONE!
# INDEX 397, DONE!
# INDEX 398, DONE!
# INDEX 399, DONE!
# /output/Imagestry11/000400.jpg
# 400 DONE!
# 000401 SHOULD EQUAL TO 401, DONE
# 401 DONE!
# INDEX 402, DONE!
# INDEX 403, DONE!
# INDEX 404, DONE!
# INDEX 405, DONE!
# INDEX 406, DONE!
# INDEX 407, DONE!
# INDEX 408, DONE!
# INDEX 409, DONE!
# INDEX 410, DONE!
# INDEX 411, DONE!
# INDEX 412, DONE!
# INDEX 413, DONE!
# INDEX 414, DONE!
# INDEX 415, DONE!
# /output/Imagestry11/000416.jpg
# 416 DONE!
# 000417 SHOULD EQUAL TO 417, DONE
# 417 DONE!
# INDEX 418, DONE!
# INDEX 419, DONE!
# INDEX 420, DONE!
# INDEX 421, DONE!
# INDEX 422, DONE!
# INDEX 423, DONE!
# INDEX 424, DONE!
# INDEX 425, DONE!
# INDEX 426, DONE!
# INDEX 427, DONE!
# INDEX 428, DONE!
# INDEX 429, DONE!
# INDEX 430, DONE!
# INDEX 431, DONE!
# /output/Imagestry11/000432.jpg
# 432 DONE!
# 000433 SHOULD EQUAL TO 433, DONE
# 433 DONE!
# INDEX 434, DONE!
# INDEX 435, DONE!
# INDEX 436, DONE!
# INDEX 437, DONE!
# INDEX 438, DONE!
# INDEX 439, DONE!
# INDEX 440, DONE!
# INDEX 441, DONE!
# INDEX 442, DONE!
# INDEX 443, DONE!
# INDEX 444, DONE!
# INDEX 445, DONE!
# INDEX 446, DONE!
# INDEX 447, DONE!
# /output/Imagestry11/000448.jpg
# 448 DONE!
# 000449 SHOULD EQUAL TO 449, DONE
# 449 DONE!
# INDEX 450, DONE!
# INDEX 451, DONE!
# INDEX 452, DONE!
# INDEX 453, DONE!
# INDEX 454, DONE!
# INDEX 455, DONE!
# INDEX 456, DONE!
# INDEX 457, DONE!
# INDEX 458, DONE!
# INDEX 459, DONE!
# INDEX 460, DONE!
# INDEX 461, DONE!
# INDEX 462, DONE!
# INDEX 463, DONE!
# /output/Imagestry11/000464.jpg
# 464 DONE!
# 000465 SHOULD EQUAL TO 465, DONE
# 465 DONE!
# INDEX 466, DONE!
# INDEX 467, DONE!
# INDEX 468, DONE!
# INDEX 469, DONE!
# INDEX 470, DONE!
# INDEX 471, DONE!
# INDEX 472, DONE!
# INDEX 473, DONE!
# INDEX 474, DONE!
# INDEX 475, DONE!
# INDEX 476, DONE!
# INDEX 477, DONE!
# INDEX 478, DONE!
# INDEX 479, DONE!
# /output/Imagestry11/000480.jpg
# 480 DONE!
# 000481 SHOULD EQUAL TO 481, DONE
# 481 DONE!
# INDEX 482, DONE!
# INDEX 483, DONE!
# INDEX 484, DONE!
# INDEX 485, DONE!
# INDEX 486, DONE!
# INDEX 487, DONE!
# INDEX 488, DONE!
# INDEX 489, DONE!
# INDEX 490, DONE!
# INDEX 491, DONE!
# INDEX 492, DONE!
# INDEX 493, DONE!
# INDEX 494, DONE!
# INDEX 495, DONE!
# /output/Imagestry11/000496.jpg
# 496 DONE!
# 000497 SHOULD EQUAL TO 497, DONE
# 497 DONE!
# INDEX 498, DONE!
# INDEX 499, DONE!
# INDEX 500, DONE!
# INDEX 501, DONE!
# INDEX 502, DONE!
# INDEX 503, DONE!
# INDEX 504, DONE!
# INDEX 505, DONE!
# INDEX 506, DONE!
# INDEX 507, DONE!
# INDEX 508, DONE!
# INDEX 509, DONE!
# INDEX 510, DONE!
# INDEX 511, DONE!
# /output/Imagestry11/000512.jpg
# 512 DONE!
# 000513 SHOULD EQUAL TO 513, DONE
# 513 DONE!
# INDEX 514, DONE!
# INDEX 515, DONE!
# INDEX 516, DONE!
# INDEX 517, DONE!
# INDEX 518, DONE!
# INDEX 519, DONE!
# INDEX 520, DONE!
# INDEX 521, DONE!
# INDEX 522, DONE!
# INDEX 523, DONE!
# INDEX 524, DONE!
# INDEX 525, DONE!
# INDEX 526, DONE!
# INDEX 527, DONE!
# /output/Imagestry11/000528.jpg
# 528 DONE!
# 000529 SHOULD EQUAL TO 529, DONE
# 529 DONE!
# INDEX 530, DONE!
# INDEX 531, DONE!
# INDEX 532, DONE!
# INDEX 533, DONE!
# INDEX 534, DONE!
# INDEX 535, DONE!
# INDEX 536, DONE!
# INDEX 537, DONE!
# INDEX 538, DONE!
# INDEX 539, DONE!
# INDEX 540, DONE!
# INDEX 541, DONE!
# INDEX 542, DONE!
# INDEX 543, DONE!
# /output/Imagestry11/000544.jpg
# 544 DONE!
# 000545 SHOULD EQUAL TO 545, DONE
# 545 DONE!
# INDEX 546, DONE!
# INDEX 547, DONE!
# INDEX 548, DONE!
# INDEX 549, DONE!
# INDEX 550, DONE!
# INDEX 551, DONE!
# INDEX 552, DONE!
# INDEX 553, DONE!
# INDEX 554, DONE!
# INDEX 555, DONE!
# INDEX 556, DONE!
# INDEX 557, DONE!
# INDEX 558, DONE!
# INDEX 559, DONE!
# /output/Imagestry11/000560.jpg
# 560 DONE!
# 000561 SHOULD EQUAL TO 561, DONE
# 561 DONE!
# INDEX 562, DONE!
# INDEX 563, DONE!
# INDEX 564, DONE!
# INDEX 565, DONE!
# INDEX 566, DONE!
# INDEX 567, DONE!
# INDEX 568, DONE!
# INDEX 569, DONE!
# INDEX 570, DONE!
# INDEX 571, DONE!
# INDEX 572, DONE!
# INDEX 573, DONE!
# INDEX 574, DONE!
# INDEX 575, DONE!
# /output/Imagestry11/000576.jpg
# 576 DONE!
# 000577 SHOULD EQUAL TO 577, DONE
# 577 DONE!
# INDEX 578, DONE!
# INDEX 579, DONE!
# INDEX 580, DONE!
# INDEX 581, DONE!
# INDEX 582, DONE!
# INDEX 583, DONE!
# INDEX 584, DONE!
# INDEX 585, DONE!
# INDEX 586, DONE!
# INDEX 587, DONE!
# INDEX 588, DONE!
# INDEX 589, DONE!
# INDEX 590, DONE!
# INDEX 591, DONE!
# /output/Imagestry11/000592.jpg
# 592 DONE!
# 000593 SHOULD EQUAL TO 593, DONE
# 593 DONE!
# INDEX 594, DONE!
# INDEX 595, DONE!
# INDEX 596, DONE!
# INDEX 597, DONE!
# INDEX 598, DONE!
# INDEX 599, DONE!
# INDEX 600, DONE!
# INDEX 601, DONE!
# INDEX 602, DONE!
# INDEX 603, DONE!
# INDEX 604, DONE!
# INDEX 605, DONE!
# INDEX 606, DONE!
# INDEX 607, DONE!
# /output/Imagestry11/000608.jpg
# 608 DONE!
# 000609 SHOULD EQUAL TO 609, DONE
# 609 DONE!
# INDEX 610, DONE!
# INDEX 611, DONE!
# INDEX 612, DONE!
# INDEX 613, DONE!
# INDEX 614, DONE!
# INDEX 615, DONE!
# INDEX 616, DONE!
# INDEX 617, DONE!
# INDEX 618, DONE!
# INDEX 619, DONE!
# INDEX 620, DONE!
# INDEX 621, DONE!
# INDEX 622, DONE!
# INDEX 623, DONE!
# /output/Imagestry11/000624.jpg
# 624 DONE!
# 000625 SHOULD EQUAL TO 625, DONE
# 625 DONE!
# INDEX 626, DONE!
# INDEX 627, DONE!
# INDEX 628, DONE!
# INDEX 629, DONE!
# INDEX 630, DONE!
# INDEX 631, DONE!
# INDEX 632, DONE!
# INDEX 633, DONE!
# INDEX 634, DONE!
# INDEX 635, DONE!
# INDEX 636, DONE!
# INDEX 637, DONE!
# INDEX 638, DONE!
# INDEX 639, DONE!
# /output/Imagestry11/000640.jpg
# 640 DONE!
# 000641 SHOULD EQUAL TO 641, DONE
# 641 DONE!
# INDEX 642, DONE!
# INDEX 643, DONE!
# INDEX 644, DONE!
# INDEX 645, DONE!
# INDEX 646, DONE!
# INDEX 647, DONE!
# INDEX 648, DONE!
# INDEX 649, DONE!
# INDEX 650, DONE!
# INDEX 651, DONE!
# INDEX 652, DONE!
# INDEX 653, DONE!
# INDEX 654, DONE!
# INDEX 655, DONE!
# /output/Imagestry11/000656.jpg
# 656 DONE!
# 000657 SHOULD EQUAL TO 657, DONE
# 657 DONE!
# INDEX 658, DONE!
# INDEX 659, DONE!
# INDEX 660, DONE!
# INDEX 661, DONE!
# INDEX 662, DONE!
# INDEX 663, DONE!
# INDEX 664, DONE!
# INDEX 665, DONE!
# INDEX 666, DONE!
# INDEX 667, DONE!
# INDEX 668, DONE!
# INDEX 669, DONE!
# INDEX 670, DONE!
# INDEX 671, DONE!
# /output/Imagestry11/000672.jpg
# 672 DONE!
# 000673 SHOULD EQUAL TO 673, DONE
# 673 DONE!
# INDEX 674, DONE!
# INDEX 675, DONE!
# INDEX 676, DONE!
# INDEX 677, DONE!
# INDEX 678, DONE!
# INDEX 679, DONE!
# INDEX 680, DONE!
# INDEX 681, DONE!
# INDEX 682, DONE!
# INDEX 683, DONE!
# INDEX 684, DONE!
# INDEX 685, DONE!
# INDEX 686, DONE!
# INDEX 687, DONE!
# /output/Imagestry11/000688.jpg
# 688 DONE!
# 000689 SHOULD EQUAL TO 689, DONE
# 689 DONE!
# INDEX 690, DONE!
# INDEX 691, DONE!
# INDEX 692, DONE!
# INDEX 693, DONE!
# INDEX 694, DONE!
# INDEX 695, DONE!
# INDEX 696, DONE!
# INDEX 697, DONE!
# INDEX 698, DONE!
# INDEX 699, DONE!
# INDEX 700, DONE!
# INDEX 701, DONE!
# INDEX 702, DONE!
# INDEX 703, DONE!
# /output/Imagestry11/000704.jpg
# 704 DONE!
# 000705 SHOULD EQUAL TO 705, DONE
# 705 DONE!
# INDEX 706, DONE!
# INDEX 707, DONE!
# INDEX 708, DONE!
# INDEX 709, DONE!
# INDEX 710, DONE!
# INDEX 711, DONE!
# INDEX 712, DONE!
# INDEX 713, DONE!
# INDEX 714, DONE!
# INDEX 715, DONE!
# INDEX 716, DONE!
# INDEX 717, DONE!
# INDEX 718, DONE!
# INDEX 719, DONE!
# /output/Imagestry11/000720.jpg
# 720 DONE!
# 000721 SHOULD EQUAL TO 721, DONE
# 721 DONE!
# INDEX 722, DONE!
# INDEX 723, DONE!
# INDEX 724, DONE!
# INDEX 725, DONE!
# INDEX 726, DONE!
# INDEX 727, DONE!
# INDEX 728, DONE!
# INDEX 729, DONE!
# INDEX 730, DONE!
# INDEX 731, DONE!
# INDEX 732, DONE!
# INDEX 733, DONE!
# INDEX 734, DONE!
# INDEX 735, DONE!
# /output/Imagestry11/000736.jpg
# 736 DONE!
# 000737 SHOULD EQUAL TO 737, DONE
# 737 DONE!
# INDEX 738, DONE!
# INDEX 739, DONE!
# INDEX 740, DONE!
# INDEX 741, DONE!
# INDEX 742, DONE!
# INDEX 743, DONE!
# INDEX 744, DONE!
# INDEX 745, DONE!
# INDEX 746, DONE!
# INDEX 747, DONE!
# INDEX 748, DONE!
# INDEX 749, DONE!
# INDEX 750, DONE!
# INDEX 751, DONE!
# /output/Imagestry11/000752.jpg
# 752 DONE!
# 000753 SHOULD EQUAL TO 753, DONE
# 753 DONE!
# INDEX 754, DONE!
# INDEX 755, DONE!
# INDEX 756, DONE!
# INDEX 757, DONE!
# INDEX 758, DONE!
# INDEX 759, DONE!
# INDEX 760, DONE!
# INDEX 761, DONE!
# INDEX 762, DONE!
# INDEX 763, DONE!
# INDEX 764, DONE!
# INDEX 765, DONE!
# INDEX 766, DONE!
# INDEX 767, DONE!
# /output/Imagestry11/000768.jpg
# 768 DONE!
# 000769 SHOULD EQUAL TO 769, DONE
# 769 DONE!
# INDEX 770, DONE!
# INDEX 771, DONE!
# INDEX 772, DONE!
# INDEX 773, DONE!
# INDEX 774, DONE!
# INDEX 775, DONE!
# INDEX 776, DONE!
# INDEX 777, DONE!
# INDEX 778, DONE!
# INDEX 779, DONE!
# INDEX 780, DONE!
# INDEX 781, DONE!
# INDEX 782, DONE!
# INDEX 783, DONE!
# /output/Imagestry11/000784.jpg
# 784 DONE!
# 000785 SHOULD EQUAL TO 785, DONE
# 785 DONE!
# INDEX 786, DONE!
# INDEX 787, DONE!
# INDEX 788, DONE!
# INDEX 789, DONE!
# INDEX 790, DONE!
# INDEX 791, DONE!
# INDEX 792, DONE!
# INDEX 793, DONE!
# INDEX 794, DONE!
# INDEX 795, DONE!
# INDEX 796, DONE!
# INDEX 797, DONE!
# INDEX 798, DONE!
# INDEX 799, DONE!
# /output/Imagestry11/000800.jpg
# 800 DONE!
# 000801 SHOULD EQUAL TO 801, DONE
# 801 DONE!
# INDEX 802, DONE!
# INDEX 803, DONE!
# INDEX 804, DONE!
# INDEX 805, DONE!
# INDEX 806, DONE!
# INDEX 807, DONE!
# INDEX 808, DONE!
# INDEX 809, DONE!
# INDEX 810, DONE!
# INDEX 811, DONE!
# INDEX 812, DONE!
# INDEX 813, DONE!
# INDEX 814, DONE!
# INDEX 815, DONE!
# /output/Imagestry11/000816.jpg
# 816 DONE!
# 000817 SHOULD EQUAL TO 817, DONE
# 817 DONE!
# INDEX 818, DONE!
# INDEX 819, DONE!
# INDEX 820, DONE!
# INDEX 821, DONE!
# INDEX 822, DONE!
# INDEX 823, DONE!
# INDEX 824, DONE!
# INDEX 825, DONE!
# INDEX 826, DONE!
# INDEX 827, DONE!
# INDEX 828, DONE!
# INDEX 829, DONE!
# INDEX 830, DONE!
# INDEX 831, DONE!
# /output/Imagestry11/000832.jpg
# 832 DONE!
# 000833 SHOULD EQUAL TO 833, DONE
# 833 DONE!
# INDEX 834, DONE!
# INDEX 835, DONE!
# INDEX 836, DONE!
# INDEX 837, DONE!
# INDEX 838, DONE!
# INDEX 839, DONE!
# INDEX 840, DONE!
# INDEX 841, DONE!
# INDEX 842, DONE!
# INDEX 843, DONE!
# INDEX 844, DONE!
# INDEX 845, DONE!
# INDEX 846, DONE!
# INDEX 847, DONE!
# /output/Imagestry11/000848.jpg
# 848 DONE!
# 000849 SHOULD EQUAL TO 849, DONE
# 849 DONE!
# INDEX 850, DONE!
# INDEX 851, DONE!
# INDEX 852, DONE!
# INDEX 853, DONE!
# INDEX 854, DONE!
# INDEX 855, DONE!
# INDEX 856, DONE!
# INDEX 857, DONE!
# INDEX 858, DONE!
# INDEX 859, DONE!
# INDEX 860, DONE!
# INDEX 861, DONE!
# INDEX 862, DONE!
# INDEX 863, DONE!
# /output/Imagestry11/000864.jpg
# 864 DONE!
# 000865 SHOULD EQUAL TO 865, DONE
# 865 DONE!
# INDEX 866, DONE!
# INDEX 867, DONE!
# INDEX 868, DONE!
# INDEX 869, DONE!
# INDEX 870, DONE!
# INDEX 871, DONE!
# INDEX 872, DONE!
# INDEX 873, DONE!
# INDEX 874, DONE!
# INDEX 875, DONE!
# INDEX 876, DONE!
# INDEX 877, DONE!
# INDEX 878, DONE!
# INDEX 879, DONE!
# /output/Imagestry11/000880.jpg
# 880 DONE!
# 000881 SHOULD EQUAL TO 881, DONE
# 881 DONE!
# INDEX 882, DONE!
# INDEX 883, DONE!
# INDEX 884, DONE!
# INDEX 885, DONE!
# INDEX 886, DONE!
# INDEX 887, DONE!
# INDEX 888, DONE!
# INDEX 889, DONE!
# INDEX 890, DONE!
# INDEX 891, DONE!
# INDEX 892, DONE!
# INDEX 893, DONE!
# INDEX 894, DONE!
# INDEX 895, DONE!
# /output/Imagestry11/000896.jpg
# 896 DONE!
# 000897 SHOULD EQUAL TO 897, DONE
# 897 DONE!
# INDEX 898, DONE!
# INDEX 899, DONE!
# INDEX 900, DONE!
# INDEX 901, DONE!
# INDEX 902, DONE!
# INDEX 903, DONE!
# INDEX 904, DONE!
# INDEX 905, DONE!
# INDEX 906, DONE!
# INDEX 907, DONE!
# INDEX 908, DONE!
# INDEX 909, DONE!
# INDEX 910, DONE!
# INDEX 911, DONE!
# /output/Imagestry11/000912.jpg
# 912 DONE!
# 000913 SHOULD EQUAL TO 913, DONE
# 913 DONE!
# INDEX 914, DONE!
# INDEX 915, DONE!
# INDEX 916, DONE!
# INDEX 917, DONE!
# INDEX 918, DONE!
# INDEX 919, DONE!
# INDEX 920, DONE!
# INDEX 921, DONE!
# INDEX 922, DONE!
# INDEX 923, DONE!
# INDEX 924, DONE!
# INDEX 925, DONE!
# INDEX 926, DONE!
# INDEX 927, DONE!
# /output/Imagestry11/000928.jpg
# 928 DONE!
# 000929 SHOULD EQUAL TO 929, DONE
# 929 DONE!
# INDEX 930, DONE!
# INDEX 931, DONE!
# INDEX 932, DONE!
# INDEX 933, DONE!
# INDEX 934, DONE!
# INDEX 935, DONE!
# INDEX 936, DONE!
# INDEX 937, DONE!
# INDEX 938, DONE!
# INDEX 939, DONE!
# INDEX 940, DONE!
# INDEX 941, DONE!
# INDEX 942, DONE!
# INDEX 943, DONE!
# /output/Imagestry11/000944.jpg
# 944 DONE!
# 000945 SHOULD EQUAL TO 945, DONE
# 945 DONE!
# INDEX 946, DONE!
# INDEX 947, DONE!
# INDEX 948, DONE!
# INDEX 949, DONE!
# INDEX 950, DONE!
# INDEX 951, DONE!
# INDEX 952, DONE!
# INDEX 953, DONE!
# INDEX 954, DONE!
# INDEX 955, DONE!
# INDEX 956, DONE!
# INDEX 957, DONE!
# INDEX 958, DONE!
# INDEX 959, DONE!
# /output/Imagestry11/000960.jpg
# 960 DONE!
# 000961 SHOULD EQUAL TO 961, DONE
# 961 DONE!
# INDEX 962, DONE!
# INDEX 963, DONE!
# INDEX 964, DONE!
# INDEX 965, DONE!
# INDEX 966, DONE!
# INDEX 967, DONE!
# INDEX 968, DONE!
# INDEX 969, DONE!
# INDEX 970, DONE!
# INDEX 971, DONE!
# INDEX 972, DONE!
# INDEX 973, DONE!
# INDEX 974, DONE!
# INDEX 975, DONE!
# /output/Imagestry11/000976.jpg
# 976 DONE!
# 000977 SHOULD EQUAL TO 977, DONE
# 977 DONE!
# INDEX 978, DONE!
# INDEX 979, DONE!
# INDEX 980, DONE!
# INDEX 981, DONE!
# INDEX 982, DONE!
# INDEX 983, DONE!
# INDEX 984, DONE!
# INDEX 985, DONE!
# INDEX 986, DONE!
# INDEX 987, DONE!
# INDEX 988, DONE!
# INDEX 989, DONE!
# INDEX 990, DONE!
# INDEX 991, DONE!
# /output/Imagestry11/000992.jpg
# 992 DONE!
# 000993 SHOULD EQUAL TO 993, DONE
# 993 DONE!
# INDEX 994, DONE!
# INDEX 995, DONE!
# INDEX 996, DONE!
# INDEX 997, DONE!
# INDEX 998, DONE!
# INDEX 999, DONE!
# INDEX 1000, DONE!
# INDEX 1001, DONE!
# INDEX 1002, DONE!
# INDEX 1003, DONE!
# INDEX 1004, DONE!
# INDEX 1005, DONE!
# INDEX 1006, DONE!
# INDEX 1007, DONE!
# /output/Imagestry11/001008.jpg
# 1008 DONE!
# 001009 SHOULD EQUAL TO 1009, DONE
# 1009 DONE!
# INDEX 1010, DONE!
# INDEX 1011, DONE!
# INDEX 1012, DONE!
# INDEX 1013, DONE!
# INDEX 1014, DONE!
# INDEX 1015, DONE!
# INDEX 1016, DONE!
# INDEX 1017, DONE!
# INDEX 1018, DONE!
# INDEX 1019, DONE!
# INDEX 1020, DONE!
# INDEX 1021, DONE!
# INDEX 1022, DONE!
# INDEX 1023, DONE!
# /output/Imagestry11/001024.jpg
# 1024 DONE!
# 001025 SHOULD EQUAL TO 1025, DONE
# 1025 DONE!
# INDEX 1026, DONE!
# INDEX 1027, DONE!
# INDEX 1028, DONE!
# INDEX 1029, DONE!
# INDEX 1030, DONE!
# INDEX 1031, DONE!
# INDEX 1032, DONE!
# INDEX 1033, DONE!
# INDEX 1034, DONE!
# INDEX 1035, DONE!
# INDEX 1036, DONE!
# INDEX 1037, DONE!
# INDEX 1038, DONE!
# INDEX 1039, DONE!
# /output/Imagestry11/001040.jpg
# 1040 DONE!
# 001041 SHOULD EQUAL TO 1041, DONE
# 1041 DONE!
# INDEX 1042, DONE!
# INDEX 1043, DONE!
# INDEX 1044, DONE!
# INDEX 1045, DONE!
# INDEX 1046, DONE!
# INDEX 1047, DONE!
# INDEX 1048, DONE!
# INDEX 1049, DONE!
# INDEX 1050, DONE!
# INDEX 1051, DONE!
# INDEX 1052, DONE!
# INDEX 1053, DONE!
# INDEX 1054, DONE!
# INDEX 1055, DONE!
# /output/Imagestry11/001056.jpg
# 1056 DONE!
# 001057 SHOULD EQUAL TO 1057, DONE
# 1057 DONE!
# INDEX 1058, DONE!
# INDEX 1059, DONE!
# INDEX 1060, DONE!
# INDEX 1061, DONE!
# INDEX 1062, DONE!
# INDEX 1063, DONE!
# INDEX 1064, DONE!
# INDEX 1065, DONE!
# INDEX 1066, DONE!
# INDEX 1067, DONE!
# INDEX 1068, DONE!
# INDEX 1069, DONE!
# INDEX 1070, DONE!
# INDEX 1071, DONE!
# /output/Imagestry11/001072.jpg
# 1072 DONE!
